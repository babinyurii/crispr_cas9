# %% [markdown]
# ## Instruction for guys from HBV cripr/cas9 research group:
#
# 1. create a folder named <span style="background-color:lightgrey">input_data</span> in the current directory and paste your files in 'fasta' format into it
#
# 2. To count indels, click on the cell below which contains the following code:
#
# ```python
# %run ./crispr_cas9_scripts/crispr_count_indels.py
# ```
#
#
# after that to run the script do one of the following:
# - click <span style="background-color:lightgrey">Run</span> button on the panel above
# - or press <span style="background-color:lightgrey">Shift + Enter</span> or <span style="background-color:lightgrey">Ctrl + Enter</span>
#
#
# when the script finishes its work, the results will be written into the folder <span style="background-color:lightgrey">output_indels</span>  in the current directory
#
#
# 3. To create plots using the excel spreadsheets made by the previous command, click on the next cell with the code:
#
# ```python
# %run ./crispr_cas9_scripts/crispr_create_plots.py
# ```
# and again to run the script do one of the following:
# - click <span style="background-color:lightgrey">Run</span> button on the panel above
# - or press <span style="background-color:lightgrey">Shift + Enter</span> or <span style="background-color:lightgrey">Ctrl + Enter</span>
#
# when this script finishes its work, the results will be written into the folder <span style="background-color:lightgrey">output_plots</span>  in the current directory
#
#
#
#
#
# NOTES:
# - if you want to stop running script, click <span style="background-color:lightgrey">stop</span> button on the panel above (which is black square).

# %%
# %run ./crispr_cas9_scripts/crispr_count_indels.py
# Out:
#     ---------------
#     job started at 2018-10-24 11:09:59 ...
#     ---------------
#
# processing file 'DK-14-10_S218_R1_1_400,510R.fasta'
# file 'DK-14-10_S218_R1_1_400,510R' processing finished at: 2018-10-24 11:10:47
#
# processing file 'DK-14-3_S220_R1_1_1,096,545R.fasta'
# file 'DK-14-3_S220_R1_1_1,096,545R' processing finished at: 2018-10-24 11:11:07
#
# processing file 'DK-14-5_S221_R1_001 assembled to OT14-5.fasta'
# file 'DK-14-5_S221_R1_001 assembled to OT14-5' processing finished at: 2018-10-24 11:11:14
#
# processing file 'DK-cas14-10_S228_R1_1_415,741R.fasta'
# file 'DK-cas14-10_S228_R1_1_415,741R' processing finished at: 2018-10-24 11:11:20
#
# processing file 'DK-cas14-10_S228_R1_2.fasta'
# file 'DK-cas14-10_S228_R1_2' processing finished at: 2018-10-24 11:11:26
#
# processing file 'DK-cas14-10_S228_R1_3.fasta'
# file 'DK-cas14-10_S228_R1_3' processing finished at: 2018-10-24 11:11:33
#
# processing file 'DK-cas14-10_S228_R2_001 assembled to ST 10 off.fasta'
# file 'DK-cas14-10_S228_R2_001 assembled to ST 10 off' processing finished at: 2018-10-24 11:11:46
#
# processing file 'DK-cas14-3_S230_R1_001 assembled to OT14-3.fasta'
# file 'DK-cas14-3_S230_R1_001 assembled to OT14-3' processing finished at: 2018-10-24 11:11:52
#
# processing file 'DK-cas14-5_S231_R1_1_717,246.fasta'
# file 'DK-cas14-5_S231_R1_1_717,246' processing finished at: 2018-10-24 11:12:13
#
# processing file 'DK-cas14-5_S231_R1_2 (1).fasta'
# file 'DK-cas14-5_S231_R1_2 (1)' processing finished at: 2018-10-24 11:12:15
#
# processing file 'DK-cas14-5_S231_R1_2.fasta'
# file 'DK-cas14-5_S231_R1_2' processing finished at: 2018-10-24 11:12:17
#
# processing file 'DK-cas14-5_S231_R1_3 (1).fasta'
# file 'DK-cas14-5_S231_R1_3 (1)' processing finished at: 2018-10-24 11:12:19
#
# processing file 'DK-cas14-5_S231_R1_3.fasta'
# file 'DK-cas14-5_S231_R1_3' processing finished at: 2018-10-24 11:12:20
#
# processing file 'DK-cas14-5_S231_R1_4 (1).fasta'
# file 'DK-cas14-5_S231_R1_4 (1)' processing finished at: 2018-10-24 11:12:22
#
# processing file 'DK-cas14-5_S231_R1_4.fasta'
# file 'DK-cas14-5_S231_R1_4' processing finished at: 2018-10-24 11:12:24
#
# processing file 'DK-cas14-5_S231_R1_5 (1).fasta'
# file 'DK-cas14-5_S231_R1_5 (1)' processing finished at: 2018-10-24 11:12:26
#
# processing file 'DK-cas14-5_S231_R1_5.fasta'
# file 'DK-cas14-5_S231_R1_5' processing finished at: 2018-10-24 11:12:28
#
# processing file 'DK-St4-4_S100_R1_001 assembled to St4-4Ref.fasta'
# file 'DK-St4-4_S100_R1_001 assembled to St4-4Ref' processing finished at: 2018-10-24 11:12:33
#
# processing file 'DK-StK4-1_S103_R1_001 assembled to St4 1 2.fasta'
#
#                       warning: it seems that the file DK-StK4-1_S103_R1_001 assembled to St4 1 2.fasta
#                       has no reference sequence as the first record.
#                       please, check it out
#                       the file will be skipped. error: Length mismatch: Expected axis has 28 elements, new values have 27 elements
#
# file 'DK-StK4-1_S103_R1_001 assembled to St4 1 2' processing finished at: 2018-10-24 11:12:50
#
# processing file 'DK-StK4-4_S120_R1_001 assembled to St4-4Ref Result.fasta'
# file 'DK-StK4-4_S120_R1_001 assembled to St4-4Ref Result' processing finished at: 2018-10-24 11:12:55
#
# processing file 'NEW DK-14-5_S221_R1_001 assembled to OT14-5.fasta'
# file 'NEW DK-14-5_S221_R1_001 assembled to OT14-5' processing finished at: 2018-10-24 11:13:01
#
#
#
#     file processed: 21
#     time taken: 0.0 hours 3.0 minutes 2 seconds
#
#     the results are in the folder 'output_indels'
#
#     ---------------
#     ... job finished at 2018-10-24 11:13:01
#     ---------------

# %%
# %run ./crispr_cas9_scripts/crispr_create_plots.py
# Out:
#     ---------------
#     job started at 2018-10-24 11:16:38 ...
#     ---------------
#
#
# processing file '1_no_coverage_tab.xlsx'
# warning: coverage can't be derived from the file
#
# processing file '2_empty_insertions_tab.xlsx'
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file 2_empty_insertions_tab.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file '2_empty_insertions_tab.xlsx' processing finished at: 2018-10-24 11:16:40
#
#
# processing file '3_empty_deletions_tab.xlsx'
#
#                           warning: perhaps the excel tab "deletions" has no data.
#                           the deletions for file 3_empty_deletions_tab.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file '3_empty_deletions_tab.xlsx' processing finished at: 2018-10-24 11:16:40
#
#
# processing file '4_empty_deletions_and_insertion.xlsx'
#
#                           warning: perhaps the excel tab "deletions" has no data.
#                           the deletions for file 4_empty_deletions_and_insertion.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file 4_empty_deletions_and_insertion.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file '4_empty_deletions_and_insertion.xlsx' processing finished at: 2018-10-24 11:16:40
#
#
# processing file '5_good_file.xlsx'
# file '5_good_file.xlsx' processing finished at: 2018-10-24 11:16:42
#
#
# processing file 'DK-14-10_S218_R1_1_400,510R.xlsx'
# file 'DK-14-10_S218_R1_1_400,510R.xlsx' processing finished at: 2018-10-24 11:16:43
#
#
# processing file 'DK-14-3_S220_R1_1_1,096,545R.xlsx'
# file 'DK-14-3_S220_R1_1_1,096,545R.xlsx' processing finished at: 2018-10-24 11:16:44
#
#
# processing file 'DK-14-5_S221_R1_001 assembled to OT14-5.xlsx'
# file 'DK-14-5_S221_R1_001 assembled to OT14-5.xlsx' processing finished at: 2018-10-24 11:16:46
#
#
# processing file 'DK-cas14-10_S228_R1_1_415,741R.xlsx'
# file 'DK-cas14-10_S228_R1_1_415,741R.xlsx' processing finished at: 2018-10-24 11:16:52
#
#
# processing file 'DK-cas14-10_S228_R1_2.xlsx'
# file 'DK-cas14-10_S228_R1_2.xlsx' processing finished at: 2018-10-24 11:16:53
#
#
# processing file 'DK-cas14-10_S228_R1_3.xlsx'
# file 'DK-cas14-10_S228_R1_3.xlsx' processing finished at: 2018-10-24 11:16:58
#
#
# processing file 'DK-cas14-10_S228_R2_001 assembled to ST 10 off.xlsx'
# file 'DK-cas14-10_S228_R2_001 assembled to ST 10 off.xlsx' processing finished at: 2018-10-24 11:17:13
#
#
# processing file 'DK-cas14-3_S230_R1_001 assembled to OT14-3.xlsx'
# file 'DK-cas14-3_S230_R1_001 assembled to OT14-3.xlsx' processing finished at: 2018-10-24 11:17:14
#
#
# processing file 'DK-cas14-5_S231_R1_1_717,246.xlsx'
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file DK-cas14-5_S231_R1_1_717,246.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file 'DK-cas14-5_S231_R1_1_717,246.xlsx' processing finished at: 2018-10-24 11:17:15
#
#
# processing file 'DK-cas14-5_S231_R1_2 (1).xlsx'
# file 'DK-cas14-5_S231_R1_2 (1).xlsx' processing finished at: 2018-10-24 11:17:16
#
#
# processing file 'DK-cas14-5_S231_R1_2.xlsx'
# file 'DK-cas14-5_S231_R1_2.xlsx' processing finished at: 2018-10-24 11:17:18
#
#
# processing file 'DK-cas14-5_S231_R1_3 (1).xlsx'
#
#                           warning: perhaps the excel tab "deletions" has no data.
#                           the deletions for file DK-cas14-5_S231_R1_3 (1).xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file DK-cas14-5_S231_R1_3 (1).xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file 'DK-cas14-5_S231_R1_3 (1).xlsx' processing finished at: 2018-10-24 11:17:18
#
#
# processing file 'DK-cas14-5_S231_R1_3.xlsx'
#
#                           warning: perhaps the excel tab "deletions" has no data.
#                           the deletions for file DK-cas14-5_S231_R1_3.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file DK-cas14-5_S231_R1_3.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file 'DK-cas14-5_S231_R1_3.xlsx' processing finished at: 2018-10-24 11:17:18
#
#
# processing file 'DK-cas14-5_S231_R1_4 (1).xlsx'
# file 'DK-cas14-5_S231_R1_4 (1).xlsx' processing finished at: 2018-10-24 11:17:19
#
#
# processing file 'DK-cas14-5_S231_R1_4.xlsx'
# file 'DK-cas14-5_S231_R1_4.xlsx' processing finished at: 2018-10-24 11:17:21
#
#
# processing file 'DK-cas14-5_S231_R1_5 (1).xlsx'
# file 'DK-cas14-5_S231_R1_5 (1).xlsx' processing finished at: 2018-10-24 11:17:22
#
#
# processing file 'DK-cas14-5_S231_R1_5.xlsx'
# file 'DK-cas14-5_S231_R1_5.xlsx' processing finished at: 2018-10-24 11:17:24
#
#
# processing file 'DK-St4-4_S100_R1_001 assembled to St4-4Ref.xlsx'
# file 'DK-St4-4_S100_R1_001 assembled to St4-4Ref.xlsx' processing finished at: 2018-10-24 11:17:26
#
#
# processing file 'DK-StK4-1_S103_R1_001 assembled to St4 1 2.xlsx'
# file 'DK-StK4-1_S103_R1_001 assembled to St4 1 2.xlsx' processing finished at: 2018-10-24 11:17:27
#
#
# processing file 'DK-StK4-4_S120_R1_001 assembled to St4-4Ref Result.xlsx'
# file 'DK-StK4-4_S120_R1_001 assembled to St4-4Ref Result.xlsx' processing finished at: 2018-10-24 11:17:30
#
#
# processing file 'fasta_1.xlsx'
#
#                           warning: perhaps the excel tab "deletions" has no data.
#                           the deletions for file fasta_1.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
#
#                           warning: perhaps the excel tab "insertions" has no data.
#                           the insertions for file fasta_1.xlsx won't be written.
#                           error: max() arg is an empty sequence.
#
# file 'fasta_1.xlsx' processing finished at: 2018-10-24 11:17:30
#
#
# processing file 'NEW DK-14-5_S221_R1_001 assembled to OT14-5.xlsx'
# file 'NEW DK-14-5_S221_R1_001 assembled to OT14-5.xlsx' processing finished at: 2018-10-24 11:17:32
#
#
#
#     file processed: 26
#     time taken: 0.0 hours 0.0 minutes 54 seconds
#
#     the results are in the folder 'output_plots'
#
#     ---------------
#     ... job finished at 2018-10-24 11:17:32
#     ---------------
